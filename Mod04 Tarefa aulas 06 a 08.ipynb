# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
municipios_rj = requests.get(

   'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio')

municipios_rj.status_code
# Out:
# 200

# %%
df_municipios_rj = pd.DataFrame(municipios_rj.json()['items'])
df_municipios_rj
# Out:
#      id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0        68563        Município           Nova Iguaçu   3303500  RJ
# 1         7216        Município    São João de Meriti   3305109  RJ
# 2         7596        Município           Barra Mansa   3300407  RJ
# 3        61653        Município           Teresópolis   3305802  RJ
# 4        41862        Município  Santa Maria Madalena   3304607  RJ
# ..         ...              ...                   ...       ...  ..
# 263      21870        Município        Rio de Janeiro   3304557  RJ
# 264      42476        Município           Nova Iguaçu   3303500  RJ
# 265      11419        Município        Rio de Janeiro   3304557  RJ
# 266      11692        Município        Rio de Janeiro   3304557  RJ
# 267       9297        Município           Nova Iguaçu   3303500  RJ
#
#                   num_pvl                                   status  \
# 0    PVL02.000551/2024-39  Assinado pelo interessado (retificação)
# 1                    None                       Arquivado a pedido
# 2                    None                             Regularizado
# 3    PVL02.007127/2022-53                                 Deferido
# 4    PVL02.009405/2019-10          Em retificação pelo interessado
# ..                    ...                                      ...
# 263  00000.000000/2028-07                                 Deferido
# 264  PVL02.001006/2020-36                                 Deferido
# 265                  None                                 Deferido
# 266                  None                                 Deferido
# 267                  None                             Regularizado
#
#              num_processo        data_protocolo  \
# 0    17944.002171/2024-00  2024-05-28T17:07:11Z
# 1    17944.000523/2010-89  2012-05-02T00:00:00Z
# 2    17944.000617/2007-52  2007-06-13T00:00:00Z
# 3    17944.103775/2022-01  2022-10-19T16:18:08Z
# 4    17944.100701/2020-42  2020-02-19T13:20:58Z
# ..                    ...                   ...
# 263  17944.000312/2016-31  2016-12-21T00:00:00Z
# 264  17944.101957/2020-77  2020-06-25T15:44:47Z
# 265  17944.001440/2008-92  2008-06-13T00:00:00Z
# 266  17944.001504/2006-93  2007-04-30T00:00:00Z
# 267  17944.000949/2007-37  2007-07-25T00:00:00Z
#
#                                          tipo_operacao  \
# 0    Operação contratual interna (com garantia da U...
# 1                          Operação contratual interna
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4    Operação contratual interna (com garantia da U...
# ..                                                 ...
# 263                        Operação contratual interna
# 264                        Operação contratual interna
# 265                        Operação contratual interna
# 266                        Operação contratual interna
# 267                        Operação contratual interna
#
#                                      finalidade  \
# 0                                Infraestrutura
# 1                      Caminho da Escola 2009 A
# 2    Regularização de Dívida - Energia Elétrica
# 3                                Multissetorial
# 4                                Infraestrutura
# ..                                          ...
# 263                                       PNAFM
# 264                              Infraestrutura
# 265                    PAC - Pró-Moradia - 2008
# 266                           Saneamento básico
# 267  Regularização de Dívida - Energia Elétrica
#
#                          tipo_credor  \
# 0    Instituição Financeira Nacional
# 1    Instituição Financeira Nacional
# 2                Empresa Não Estatal
# 3    Instituição Financeira Nacional
# 4    Instituição Financeira Nacional
# ..                               ...
# 263  Instituição Financeira Nacional
# 264  Instituição Financeira Nacional
# 265  Instituição Financeira Nacional
# 266  Instituição Financeira Nacional
# 267              Empresa Não Estatal
#
#                                              credor moeda         valor  \
# 0                           Caixa Econômica Federal  Real  1.600000e+08
# 1                               Banco do Brasil S/A  Real  1.745900e+06
# 2              Light - Serviços de Eletricidade S/A  Real  1.350540e+07
# 3    Agência de Fomento do Estado do Rio de Janeiro  Real  3.500000e+07
# 4                           Caixa Econômica Federal  Real  4.770000e+06
# ..                                              ...   ...           ...
# 263                         Caixa Econômica Federal  Real  4.900000e+07
# 264                         Caixa Econômica Federal  Real  5.400000e+07
# 265                         Caixa Econômica Federal  Real  1.527289e+08
# 266                         Caixa Econômica Federal  Real  1.360000e+07
# 267            Light - Serviços de Eletricidade S/A  Real  2.315218e+06
#
#      pvl_assoc_divida  pvl_contradado_credor data_status
# 0                   0                      0  27/06/2024
# 1                   0                      0  21/05/2012
# 2                   1                      0  15/06/2007
# 3                   0                      0  21/10/2022
# 4                   0                      0  06/04/2020
# ..                ...                    ...         ...
# 263                 1                      0  28/12/2016
# 264                 1                      0  30/06/2020
# 265                 1                      0  30/06/2008
# 266                 1                      0  25/05/2007
# 267                 1                      0  02/08/2007
#
# [268 rows x 18 columns]

# %%
df_municipios_rj['uf'].value_counts()
# Out:
# uf
# RJ    268
# Name: count, dtype: int64

# %%
# 2) Seu código aqui
status_municipios_rj = df_municipios_rj.status.value_counts()

print('Os três status das solicitações mais frequentes e suas frequências:\n')
for i in range(3):
    print(f'{i+1}º {status_municipios_rj.index[i]}: {status_municipios_rj.iloc[i]}')
# Out:
# Os três status das solicitações mais frequentes e suas frequências:
#
# 1º Deferido: 106
# 2º Arquivado: 53
# 3º Regularizado: 26

# %%
# 3) Seu código aqui
# Supondo que `data_status` seja a coluna do DataFrame
df_municipios_rj['ano_status'] = df_municipios_rj['data_status'].str.slice(start=0, stop=4)

print(df_municipios_rj[['data_status', 'ano_status']].head())
# Out:
#   data_status ano_status
# 0  27/06/2024       27/0
# 1  21/05/2012       21/0
# 2  15/06/2007       15/0
# 3  21/10/2022       21/1
# 4  06/04/2020       06/0

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consultar_PVL(uf:str='SP', tipo_interessado:str='Estado') -> pd.DataFrame:
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={}&tipo_interessado={}'.format(
        uf, 
        tipo_interessado)
    r_uf = requests.get(url)  
    return pd.DataFrame(r_uf.json()['items'])

consultar_PVL('RJ', 'Município')
# Out:
#      id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0        68563        Município           Nova Iguaçu   3303500  RJ
# 1         7216        Município    São João de Meriti   3305109  RJ
# 2         7596        Município           Barra Mansa   3300407  RJ
# 3        61653        Município           Teresópolis   3305802  RJ
# 4        41862        Município  Santa Maria Madalena   3304607  RJ
# ..         ...              ...                   ...       ...  ..
# 263      21870        Município        Rio de Janeiro   3304557  RJ
# 264      42476        Município           Nova Iguaçu   3303500  RJ
# 265      11419        Município        Rio de Janeiro   3304557  RJ
# 266      11692        Município        Rio de Janeiro   3304557  RJ
# 267       9297        Município           Nova Iguaçu   3303500  RJ
#
#                   num_pvl                                   status  \
# 0    PVL02.000551/2024-39  Assinado pelo interessado (retificação)
# 1                    None                       Arquivado a pedido
# 2                    None                             Regularizado
# 3    PVL02.007127/2022-53                                 Deferido
# 4    PVL02.009405/2019-10          Em retificação pelo interessado
# ..                    ...                                      ...
# 263  00000.000000/2028-07                                 Deferido
# 264  PVL02.001006/2020-36                                 Deferido
# 265                  None                                 Deferido
# 266                  None                                 Deferido
# 267                  None                             Regularizado
#
#              num_processo        data_protocolo  \
# 0    17944.002171/2024-00  2024-05-28T17:07:11Z
# 1    17944.000523/2010-89  2012-05-02T00:00:00Z
# 2    17944.000617/2007-52  2007-06-13T00:00:00Z
# 3    17944.103775/2022-01  2022-10-19T16:18:08Z
# 4    17944.100701/2020-42  2020-02-19T13:20:58Z
# ..                    ...                   ...
# 263  17944.000312/2016-31  2016-12-21T00:00:00Z
# 264  17944.101957/2020-77  2020-06-25T15:44:47Z
# 265  17944.001440/2008-92  2008-06-13T00:00:00Z
# 266  17944.001504/2006-93  2007-04-30T00:00:00Z
# 267  17944.000949/2007-37  2007-07-25T00:00:00Z
#
#                                          tipo_operacao  \
# 0    Operação contratual interna (com garantia da U...
# 1                          Operação contratual interna
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4    Operação contratual interna (com garantia da U...
# ..                                                 ...
# 263                        Operação contratual interna
# 264                        Operação contratual interna
# 265                        Operação contratual interna
# 266                        Operação contratual interna
# 267                        Operação contratual interna
#
#                                      finalidade  \
# 0                                Infraestrutura
# 1                      Caminho da Escola 2009 A
# 2    Regularização de Dívida - Energia Elétrica
# 3                                Multissetorial
# 4                                Infraestrutura
# ..                                          ...
# 263                                       PNAFM
# 264                              Infraestrutura
# 265                    PAC - Pró-Moradia - 2008
# 266                           Saneamento básico
# 267  Regularização de Dívida - Energia Elétrica
#
#                          tipo_credor  \
# 0    Instituição Financeira Nacional
# 1    Instituição Financeira Nacional
# 2                Empresa Não Estatal
# 3    Instituição Financeira Nacional
# 4    Instituição Financeira Nacional
# ..                               ...
# 263  Instituição Financeira Nacional
# 264  Instituição Financeira Nacional
# 265  Instituição Financeira Nacional
# 266  Instituição Financeira Nacional
# 267              Empresa Não Estatal
#
#                                              credor moeda         valor  \
# 0                           Caixa Econômica Federal  Real  1.600000e+08
# 1                               Banco do Brasil S/A  Real  1.745900e+06
# 2              Light - Serviços de Eletricidade S/A  Real  1.350540e+07
# 3    Agência de Fomento do Estado do Rio de Janeiro  Real  3.500000e+07
# 4                           Caixa Econômica Federal  Real  4.770000e+06
# ..                                              ...   ...           ...
# 263                         Caixa Econômica Federal  Real  4.900000e+07
# 264                         Caixa Econômica Federal  Real  5.400000e+07
# 265                         Caixa Econômica Federal  Real  1.527289e+08
# 266                         Caixa Econômica Federal  Real  1.360000e+07
# 267            Light - Serviços de Eletricidade S/A  Real  2.315218e+06
#
#      pvl_assoc_divida  pvl_contradado_credor data_status
# 0                   0                      0  27/06/2024
# 1                   0                      0  21/05/2012
# 2                   1                      0  15/06/2007
# 3                   0                      0  21/10/2022
# 4                   0                      0  06/04/2020
# ..                ...                    ...         ...
# 263                 1                      0  28/12/2016
# 264                 1                      0  30/06/2020
# 265                 1                      0  30/06/2008
# 266                 1                      0  25/05/2007
# 267                 1                      0  02/08/2007
#
# [268 rows x 18 columns]

# %%
# 2) Seu código aqui
df_estado_mg = consultar_PVL('MG', 'Estado')
print("Solicitações do tipo Estado para Minas Gerais com status em 'Arquivado por decurso de prazo':")
print(df_estado_mg[df_estado_mg['status'] == 'Arquivado por decurso de prazo'].shape[0])
# Out:
# Solicitações do tipo Estado para Minas Gerais com status em 'Arquivado por decurso de prazo':
# 1

# %%
# 3) Seu código aqui
df_estado_ba['interessado'].value_counts().iloc[0]
print('O município da Bahia com mais solicitões deferidas é {} com {} solicitações deferidas.'.format(
    df_estado_ba['interessado'].value_counts().index[0], 
    df_estado_ba['interessado'].value_counts().iloc[0]))
# Out:
# O município da Bahia com mais solicitões deferidas é Camaçari com 21 solicitações deferidas.

# %%
# 4) Seu código aqui
df_estado_ba = consultar_PVL('BA', 'Estado')
df_estado_ba.to_csv('estado_ba.csv', index=False)
df_estado_ba
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0       23723           Estado       Bahia        29  BA
# 1       18372           Estado       Bahia        29  BA
# 2       18527           Estado       Bahia        29  BA
# 3        7433           Estado       Bahia        29  BA
# 4        8949           Estado       Bahia        29  BA
# ..        ...              ...         ...       ...  ..
# 91      69613           Estado       Bahia        29  BA
# 92      18559           Estado       Bahia        29  BA
# 93      18567           Estado       Bahia        29  BA
# 94      18571           Estado       Bahia        29  BA
# 95      18515           Estado       Bahia        29  BA
#
#                  num_pvl                                             status  \
# 0   PVL02.000640/2016-75  Encaminhado à PGFN com manifestação técnica fa...
# 1                   None                                           Deferido
# 2                   None                                           Deferido
# 3                   None  Encaminhado à PGFN com manifestação técnica fa...
# 4                   None  Encaminhado à PGFN com manifestação técnica fa...
# ..                   ...                                                ...
# 91  PVL02.001644/2024-81  Encaminhado à PGFN com manifestação técnica fa...
# 92                  None                                           Deferido
# 93                  None                                           Deferido
# 94                  None                                           Deferido
# 95                  None                                           Deferido
#
#             num_processo        data_protocolo  \
# 0   17944.001273/2016-90  2017-06-06T15:33:06Z
# 1   19407.000009/2005-99  2005-06-30T00:00:00Z
# 2   19407.000043/2002-11  2002-06-21T00:00:00Z
# 3   17944.000575/2012-17  2012-08-20T00:00:00Z
# 4   17944.000872/2014-24  2014-07-11T00:00:00Z
# ..                   ...                   ...
# 91  17944.005802/2024-34  2024-10-16T18:55:34Z
# 92  19407.000051/2002-67  2002-06-11T00:00:00Z
# 93  19407.000053/2002-56  2002-06-17T00:00:00Z
# 94  19407.000054/2002-09  2002-06-17T00:00:00Z
# 95  19407.000040/2002-87  2002-06-21T00:00:00Z
#
#                                         tipo_operacao  \
# 0   Operação contratual interna (com garantia da U...
# 1                         Operação contratual interna
# 2                         Operação contratual interna
# 3   Operação contratual externa (com garantia da U...
# 4   Operação contratual externa (com garantia da U...
# ..                                                ...
# 91  Operação contratual interna (com garantia da U...
# 92                        Operação contratual interna
# 93                        Operação contratual interna
# 94                        Operação contratual interna
# 95                        Operação contratual interna
#
#                              finalidade                           tipo_credor  \
# 0                        Infraestrutura       Instituição Financeira Nacional
# 1                     Segurança pública       Instituição Financeira Nacional
# 2                     Saneamento básico       Instituição Financeira Nacional
# 3                        Infraestrutura  Instituição Financeira Internacional
# 4                                 Saúde  Instituição Financeira Internacional
# ..                                  ...                                   ...
# 91                    Segurança pública       Instituição Financeira Nacional
# 92                    Saneamento básico       Instituição Financeira Nacional
# 93                    Saneamento básico       Instituição Financeira Nacional
# 94                       Infraestrutura       Instituição Financeira Nacional
# 95  Preservação e recuperação ambiental       Instituição Financeira Nacional
#
#                                                credor          moeda  \
# 0                                 Banco do Brasil S/A           Real
# 1                                 Banco do Brasil S/A  Dólar dos EUA
# 2                             Caixa Econômica Federal           Real
# 3   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4             Banco Interamericano de Desenvolvimento  Dólar dos EUA
# ..                                                ...            ...
# 91                      Banco Santander (Brasil) S.A.           Real
# 92                            Caixa Econômica Federal           Real
# 93                            Caixa Econômica Federal           Real
# 94                            Caixa Econômica Federal           Real
# 95                            Caixa Econômica Federal           Real
#
#            valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   6.000000e+08                 1                      1  12/06/2017
# 1   1.616050e+07                 1                      0  26/07/2005
# 2   8.626204e+06                 1                      0  05/07/2002
# 3   7.000000e+08                 1                      0  06/09/2012
# 4   2.000000e+08                 1                      0  28/07/2014
# ..           ...               ...                    ...         ...
# 91  4.000000e+08                 0                      0  05/11/2024
# 92  1.983597e+07                 1                      0  08/07/2002
# 93  2.039426e+06                 1                      0  03/07/2002
# 94  1.797522e+05                 1                      0  08/07/2002
# 95  1.893800e+07                 1                      0  08/07/2002
#
# [96 rows x 18 columns]
